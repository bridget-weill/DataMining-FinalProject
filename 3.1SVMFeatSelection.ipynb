# %% [markdown]
# # Feature Selection: Pipeline 3.1
# ### SVM Chi2

# %% [markdown]
# ### Import and Read in Data

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
data = pd.read_csv('pipeline3_1.csv', header=0)
data.head()
# Out:
#    AdministrativeSkew  Administrative_DurationSkew  InformationalSkew  \
# 0           -0.990128                    -0.996659          -0.520831
# 1           -0.990128                    -0.996659          -0.520831
# 2           -0.990128                    -0.996659          -0.520831
# 3           -0.990128                    -0.996659          -0.520831
# 4           -0.990128                    -0.996659          -0.520831
#
#    Informational_DurationSkew  ProductRelatedSkew  \
# 0                   -0.492257           -1.922123
# 1                   -0.492257           -1.574524
# 2                   -0.492257           -1.922123
# 3                   -0.492257           -1.574524
# 4                   -0.492257           -0.442610
#
#    ProductRelated_DurationSkew  BounceRatesSkew  ExitRatesSkew  \
# 0                    -2.096783         1.733188       1.982547
# 1                    -1.074189        -0.974179       1.569866
# ...

# %% [markdown]
# ### Split Features and Target

# %%
X = data.iloc[:, :74]
y = data.iloc[:, 74:75]

# %% [markdown]
# ### Select Features Using F Classif
# Need to use F CLassif since we have negative values in our data.  This is due to the order of pipeline 1.

# %%
# selecting the best features
# ref: https://medium.com/analytics-vidhya/preprocessing-data-for-predicting-online-shoppers-purchasing-intention-ml-ba78186b7e85

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

bestfeatures = SelectKBest(f_classif, k=2)

fit = bestfeatures.fit(X, y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(30, 'Score'))
# Out:
#                           Feature        Score
# 8                  PageValuesSkew  7044.451171
# 7                   ExitRatesSkew   843.209484
# 5     ProductRelated_DurationSkew   599.443724
# 4              ProductRelatedSkew   521.553036
# 0              AdministrativeSkew   357.308881
# 1     Administrative_DurationSkew   356.908849
# 73                   SeasonBins_4   341.834423
# 6                 BounceRatesSkew   305.928215
# 71                   SeasonBins_2   171.837537
# 46                  TrafficType_2   169.168817
# 2               InformationalSkew   158.582250
# 3      Informational_DurationSkew   148.677353
# 65        VisitorType_New_Visitor   135.153599
# 67  VisitorType_Returning_Visitor   134.386024
# 9                  SpecialDay_0.0    93.129717
# 47                  TrafficType_3    85.118300
# 17             OperatingSystems_3    61.530952
# 57                 TrafficType_13    56.107963
# 45                  TrafficType_1    53.772783
# ...
